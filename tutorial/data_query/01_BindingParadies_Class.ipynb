# %% [markdown]
# # The BindingParadise Class
#
# The binding paradise class was written with the goal of providing
# an easy to use interface between the BEEP database and the user. I this tutorial
# I will explain the different methods contain in the class and how to access the
# different data contained in the database. Even though this class is
# a straightforward gateway to the database, the user can also use any QCPortal
# method to access the data in the database.
#
# The first thing we will do is to create a BindingParadies object which we will call
# `bp`. The only thing the user needs to provide is a username and password.

# %%
from beep.beep import BindingParadise 

bp = BindingParadise('guest','pOg_41tzuDxkTtAfjPuUq8WK5ssbnmN8QfjsApGXVYk')

# %% [markdown]
# Next we will list all the molecules that have been included in the database thus far using the `molecule_list()` method

# %%
bp.molecules_list()
# Out:
# ['ch2o2_W22',
#  'ch3_W22',
#  'ch3o_W22',
#  'ch3oh_W22',
#  'ch4_W22',
#  'co_W22',
#  'h2_W22',
#  'h2co_W22',
#  'h2o_W22',
#  'h2s_W22',
#  'hcl_W22',
#  'hcn_W22',
#  'hco_W22',
#  'hf_W22',
#  'n2_W22',
#  'nh2_W22',
#  'nh3_W22',
#  'nhch2_W22']

# %% [markdown]
# As you can see all molecules contain the target molecule and the ice model on which the binding energies were computed for example W22, means they were computed on an a set of amorphous solid water cluster containing 22 molecules each.
#
# In this tuturial we will be interested in exploring the binding energies and binding sites of amonia (NH3). Therfore we set the molecule with the `set_molecule` method.

# %%
bp.set_molecule('nh3_W22');
# Out:
# Molecule set: NH3_W22

# %% [markdown]
# Now that a molecule has been asigned to the `bp` object we can retrive the different optimization methods of the binding sites.

# %%
bp.get_optimization_methods();
# Out:
# List of optimization methods: ['M05', 'MPWB1K-D3BJ', 'HF3C', 'PW91-D3']

# %% [markdown]
# Wow! three methods! Let's load the data of one of those three methods

# %%
bp.load_data("M05")

# %% [markdown]
# Once we have the optimization method, we must list the levels of theory of the binding energy computations for these geomtries.

# %%
bp.get_methods();
# Out:
# The available binding energy methods for M05 geometries are : ['pwb6k-d3bj', 'b3lyp-d3bj', 'b3lyp', 'pwb6k', 'mn12-l', 'mn12-l-d3bj']

# %% [markdown]
# We are finally ready to retrive the  binding energies!

# %%
df_be = bp.get_values('b3lyp-d3bj', zpve=True)

# %% [markdown]
# Notice that the return object is a pandas dataframe and that the user can select if the values should be corrected for zero-point vibrational energy or not. Let's check out the resulting dataframe with the binding energies! The nomenclature of the entries is as follows: First the molecule name (e.g. NH3), than the ASW model (W22), the number of the cluster and finally the number of the binding site on the specific cluster.

# %%
df_be
# Out:
#                 B3LYP-D3BJ/def2-tzvp B3LYP-D3BJ + ZPVE
# nh3_W22_04_0002             -8.46069          -6.30605
# nh3_W22_04_0003             -10.9358          -8.19245
# nh3_W22_04_0006             -8.84341          -6.59774
# nh3_W22_04_0007             -9.69759          -7.24875
# nh3_W22_04_0010             -9.94742          -7.43916
# nh3_W22_04_0011             -8.47533          -6.31721
# nh3_W22_04_0012              -8.8557           -6.6071
# nh3_W22_04_0013             -8.59441          -6.40797
# nh3_W22_04_0014             -9.17649          -6.85159
# nh3_W22_04_0018             -3.11623          -2.23278
# nh3_W22_04_0019             -9.03568          -6.74428
# nh3_W22_04_0021              -8.1341          -6.05714
# nh3_W22_04_0022             -2.46623          -1.73738
# nh3_W22_04_0027             -9.37631          -7.00389
# nh3_W22_04_0031             -10.3826          -7.77081
# nh3_W22_04_0034             -8.99292          -6.71168
# nh3_W22_04_0037             -8.45224          -6.29961
# nh3_W22_05_0001             -8.51875           -6.3503
# nh3_W22_05_0004             -9.28932          -6.93759
# nh3_W22_05_0005             -12.0907          -9.07268
# nh3_W22_05_0006             -8.71253          -6.49799
# nh3_W22_05_0007             -8.58546          -6.40115
# nh3_W22_05_0009             -4.13723          -3.01093
# nh3_W22_05_0010             -8.82988          -6.58742
# nh3_W22_05_0014             -7.75192          -5.76586
# nh3_W22_05_0015             -6.95208          -5.15627
# nh3_W22_05_0019             -7.96181          -5.92583
# nh3_W22_05_0023             -9.24975          -6.90743
# nh3_W22_05_0029             -4.26531          -3.10855
# nh3_W22_07_0001             -11.1067          -8.32272
# nh3_W22_07_0003             -8.61462          -6.42337
# nh3_W22_07_0004             -13.7102           -10.307
# nh3_W22_07_0005             -9.73743          -7.27911
# nh3_W22_07_0006              -8.8275          -6.58561
# nh3_W22_07_0007             -7.79542          -5.79901
# nh3_W22_07_0009             -3.04022          -2.17485
# nh3_W22_07_0011             -11.7869          -8.84114
# nh3_W22_07_0014             -9.71235             -7.26
# nh3_W22_07_0015             -8.24699          -6.14318
# nh3_W22_07_0019             -8.90207          -6.64245
# nh3_W22_07_0022             -8.67802          -6.47169
# nh3_W22_07_0023             -9.62409          -7.19273
# nh3_W22_07_0025             -9.25768          -6.91348
# nh3_W22_07_0026             -3.61673          -2.61423
# nh3_W22_07_0027             -8.14811          -6.06782
# nh3_W22_07_0034             -9.80099          -7.32756
# nh3_W22_07_0036             -9.07294          -6.77268
# nh3_W22_07_0037             -11.7676          -8.82643
# nh3_W22_07_0041              -8.4591          -6.30484
# nh3_W22_07_0043             -9.58158          -7.16033
# nh3_W22_07_0044              -10.727          -8.03331
# nh3_W22_07_0046             -11.9443          -8.96105
# nh3_W22_07_0050             -9.42725          -7.04271
# nh3_W22_07_0051             -9.70728          -7.25613
# nh3_W22_07_0054             -8.31651          -6.19616
# nh3_W22_07_0062             -10.6633          -7.98477
# nh3_W22_07_0066             -8.10881          -6.03786
# nh3_W22_07_0067             -11.5551          -8.66445
# nh3_W22_07_0071             -11.4564          -8.58922
# nh3_W22_07_0076             -10.0868          -7.54536
# nh3_W22_07_0086             -9.63914          -7.20421
# nh3_W22_07_0090             -3.84334          -2.78694
# nh3_W22_07_0095             -11.0039          -8.24436
# nh3_W22_07_0100             -3.40625          -2.45382

# %% [markdown]
# Finally we can also access the xyz coordinates of all the different binding sites (up to 250 per species!) to do this we call the `get_molecules` methods which saves the molecule objects in a Pandas dataframe.

# %%
df_mol = bp.get_molecules(method='b3lyp-d3bj')

# %%
df_mol
# Out:
#                 B3LYP-D3BJ/def2-tzvp  \
# nh3_W22_04_0002             -8.46069
# nh3_W22_04_0003             -10.9358
# nh3_W22_04_0006             -8.84341
# nh3_W22_04_0007             -9.69759
# nh3_W22_04_0010             -9.94742
# nh3_W22_04_0011             -8.47533
# nh3_W22_04_0012              -8.8557
# nh3_W22_04_0013             -8.59441
# nh3_W22_04_0014             -9.17649
# nh3_W22_04_0018             -3.11623
# nh3_W22_04_0019             -9.03568
# nh3_W22_04_0021              -8.1341
# nh3_W22_04_0022             -2.46623
# nh3_W22_04_0027             -9.37631
# nh3_W22_04_0031             -10.3826
# nh3_W22_04_0034             -8.99292
# nh3_W22_04_0037             -8.45224
# nh3_W22_05_0001             -8.51875
# nh3_W22_05_0004             -9.28932
# nh3_W22_05_0005             -12.0907
# nh3_W22_05_0006             -8.71253
# nh3_W22_05_0007             -8.58546
# nh3_W22_05_0009             -4.13723
# nh3_W22_05_0010             -8.82988
# nh3_W22_05_0014             -7.75192
# nh3_W22_05_0015             -6.95208
# nh3_W22_05_0019             -7.96181
# nh3_W22_05_0023             -9.24975
# nh3_W22_05_0029             -4.26531
# nh3_W22_07_0001             -11.1067
# nh3_W22_07_0003             -8.61462
# nh3_W22_07_0004             -13.7102
# nh3_W22_07_0005             -9.73743
# nh3_W22_07_0006              -8.8275
# nh3_W22_07_0007             -7.79542
# nh3_W22_07_0009             -3.04022
# nh3_W22_07_0011             -11.7869
# nh3_W22_07_0014             -9.71235
# nh3_W22_07_0015             -8.24699
# nh3_W22_07_0019             -8.90207
# nh3_W22_07_0022             -8.67802
# nh3_W22_07_0023             -9.62409
# nh3_W22_07_0025             -9.25768
# nh3_W22_07_0026             -3.61673
# nh3_W22_07_0027             -8.14811
# nh3_W22_07_0034             -9.80099
# nh3_W22_07_0036             -9.07294
# nh3_W22_07_0037             -11.7676
# nh3_W22_07_0041              -8.4591
# nh3_W22_07_0043             -9.58158
# nh3_W22_07_0044              -10.727
# nh3_W22_07_0046             -11.9443
# nh3_W22_07_0050             -9.42725
# nh3_W22_07_0051             -9.70728
# nh3_W22_07_0054             -8.31651
# nh3_W22_07_0062             -10.6633
# nh3_W22_07_0066             -8.10881
# nh3_W22_07_0067             -11.5551
# nh3_W22_07_0071             -11.4564
# nh3_W22_07_0076             -10.0868
# nh3_W22_07_0086             -9.63914
# nh3_W22_07_0090             -3.84334
# nh3_W22_07_0095             -11.0039
# nh3_W22_07_0100             -3.40625
# nh3_W22_07_0033                  NaN
#
#                                                           molecule
# nh3_W22_04_0002  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0003  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0006  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0007  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0010  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0011  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0012  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0013  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0014  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0018  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0019  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0021  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0022  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0027  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0031  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0034  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_04_0037  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0001  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0004  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0005  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0006  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0007  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0009  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0010  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0014  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0015  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0019  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0023  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_05_0029  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0001  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0003  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0004  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0005  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0006  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0007  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0009  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0011  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0014  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0015  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0019  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0022  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0023  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0025  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0026  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0027  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0034  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0036  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0037  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0041  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0043  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0044  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0046  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0050  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0051  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0054  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0062  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0066  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0067  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0071  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0076  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0086  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0090  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0095  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0100  Molecule(name='H47NO22', formula='H47NO22', ha...
# nh3_W22_07_0033  Molecule(name='H47NO22', formula='H47NO22', ha...

# %% [markdown]
# From the molecule object you can extract xyz coordianates and many other properties!
